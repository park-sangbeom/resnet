# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt 
import sys
from pathlib import Path
sys.path.append("..")
from model.utils_projection import *
print("Done.")
# Out:
# Done.

# %%
image = np.load("/home/sangbeom/resnet/data/depth1014/depth1_8.npy")
print("[Image Shape]:",image.shape)
print("[Image AvgVal]:",np.average(image))
print("[Image MaxVal]:",np.max(image))
print("[Image MinVal]:",np.min(image))
plt.imshow(image)

# %%
realimg1 = np.load('../data/realworld/1025_test11_norm_ortho.npy').reshape(96,192)
print("[Image Shape]:",realimg1.shape)
print("[Image AvgVal]:",np.average(realimg1))
print("[Image MaxVal]:",np.max(realimg1))
print("[Image MinVal]:",np.min(realimg1))
plt.imshow(realimg1)
# Out:
# [Image Shape]: (96, 192)
# [Image AvgVal]: 0.76469004
# [Image MaxVal]: 1.0
# [Image MinVal]: 0.0

# %%
realimg2 = np.load('../data/realworld/1025_test12_norm_ortho.npy').reshape(96,192)
print("[Image Shape]:",realimg2.shape)
print("[Image AvgVal]:",np.average(realimg2))
print("[Image MaxVal]:",np.max(realimg2))
print("[Image MinVal]:",np.min(realimg2))
plt.imshow(realimg2)
# Out:
# [Image Shape]: (96, 192)
# [Image AvgVal]: 0.82614005
# [Image MaxVal]: 1.0
# [Image MinVal]: 0.0

# %%
realimg2 = np.load('../data/realworld/1025_test10_norm.npy')
realimg2 = realworld_ortho_proejction(realimg2)
print("[Image Shape]:",realimg2.shape)
print("[Image AvgVal]:",np.average(realimg2))
print("[Image MaxVal]:",np.max(realimg2))
print("[Image MinVal]:",np.min(realimg2))
plt.imshow(realimg2)
# Out:
# [Image Shape]: (96, 192)
# [Image AvgVal]: 0.7939490426817305
# [Image MaxVal]: 1.0
# [Image MinVal]: 0.0
